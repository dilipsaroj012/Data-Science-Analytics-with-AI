# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
print(("*")*120)
print(" \t\t\t\t**************DATASET:- Top Company ***************\n\nCompany:-In the data set contains the top 2000 company by the rank and there information about sales,profit and there assets etc.\n\nOBJECTIVE:- There are the objective which is company growth rate show there market value and there find out particular compamy info.")
print(("*")*120)
# Out:
# ************************************************************************************************************************
#  				**************DATASET:- Top Company ***************
#
# Company:-In the data set contains the top 2000 company by the rank and there information about sales,profit and there assets etc.
#
# OBJECTIVE:- There are the objective which is company growth rate show there market value and there find out particular compamy info.
# ************************************************************************************************************************

# %%
df=pd.read_csv("Top2000CompaniesGlobally.csv")
df
# Out:
#       Global Rank                     Company  Sales ($billion)  \
# 0               1                        ICBC             134.8
# 1               2     China Construction Bank             113.1
# 2               3              JPMorgan Chase             108.2
# 3               4            General Electric             147.4
# 4               5                 Exxon Mobil             420.7
# ...           ...                         ...               ...
# 1919         1995              Tractor Supply               4.7
# 1920         1996                  San-Ai Oil               0.5
# 1921         1996                   UOL Group               0.9
# 1922         1998     Interconexion Electrica               2.4
# 1923         1999  Old Republic International               5.0
#
#       Profits ($billion)  Assets ($billion)  Market Value ($billion)  \
# 0                   37.8             2813.5                    237.3
# ...

# %%
print(("*")*120)
print(" \t\t\t\t**************UNDERSTANDING OF DATA GIVEN***************\n\n(a) GLOBAL RANK- It contains the global rank wise company number tha givan by bussiness world  .\n\n(b) Company Name- Company name rank wise. \n\n(c) sales- The company has overall sales.\n\n(d) Profits-In the profits of the company.\n\n(e) Assets- company has total number of assets \n\n(f) Latitude- listing latitude\n\n(g) longitude- listing longitude\n\n(h) market_value - Company has market value the market value are define share of there company. \n\n(i) Country - company has country name which they can registred there company \n\n(k) Continant-Company are belongs to there respactive country or continent")
print(("*")*120)
# Out:
# ************************************************************************************************************************
#  				**************UNDERSTANDING OF DATA GIVEN***************
#
# (a) GLOBAL RANK- It contains the global rank wise company number tha givan by bussiness world  .
#
# (b) Company Name- Company name rank wise.
#
# (c) sales- The company has overall sales.
#
# (d) Profits-In the profits of the company.
#
# (e) Assets- company has total number of assets
#
# (f) Latitude- listing latitude
#
# (g) longitude- listing longitude
#
# (h) market_value - Company has market value the market value are define share of there company.
#
# (i) Country - company has country name which they can registred there company
#
# (k) Continant-Company are belongs to there respactive country or continent
# ************************************************************************************************************************

# %% [markdown]
# # Basic Information about Dataset

# %%
print(("*")*120)
print(" \t\t\t\t**************ANALYSIS***************\n\t\t\t\tMY DATASET HAS 10 COLUMNS AND 1924 ROWS.\n\t\t\t\tIT HAS 7 NUMERICAL COLUMNS AND 3 CATEGORICAL COLUMNS.\n\t\t\t\t0 COLUMNS HAS NULL VALUES.")
print(("*")*120)
df.info()
# Out:
# ************************************************************************************************************************
#  				**************ANALYSIS***************
# 				MY DATASET HAS 10 COLUMNS AND 1924 ROWS.
# 				IT HAS 7 NUMERICAL COLUMNS AND 3 CATEGORICAL COLUMNS.
# 				0 COLUMNS HAS NULL VALUES.
# ************************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1924 entries, 0 to 1923
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Global Rank              1924 non-null   int64
#  1   Company                  1924 non-null   object
#  2   Sales ($billion)         1924 non-null   float64
#  3   Profits ($billion)       1924 non-null   float64
#  4   Assets ($billion)        1924 non-null   float64
#  5   Market Value ($billion)  1924 non-null   float64
# ...

# %% [markdown]
# # Feature of dataset

# %%
df.describe()
# Out:
#        Global Rank  Sales ($billion)  Profits ($billion)  Assets ($billion)  \
# count  1924.000000       1924.000000         1924.000000        1924.000000
# mean    997.232848         19.265904            1.226040          79.507796
# std     575.502781         34.683911            3.413831         261.098775
# min       1.000000          0.000000          -24.500000           1.000000
# 25%     500.750000          4.100000            0.300000           9.675000
# 50%     997.500000          9.000000            0.600000          19.250000
# 75%    1494.250000         18.425000            1.200000          45.800000
# max    1999.000000        469.200000           44.900000        3226.200000
#
#        Market Value ($billion)     Latitude    Longitude
# count              1924.000000  1924.000000  1924.000000
# mean                 19.558160    34.618747    15.455664
# std                  32.957023    18.259499    92.639655
# ...

# %% [markdown]
# # SEPARATING NUMERICAL AND CATEGORICAL COLUMNS

# %%
num_cols=df.select_dtypes(include=["int","float"])
num_cols
# Out:
#       Global Rank  Sales ($billion)  Profits ($billion)  Assets ($billion)  \
# 0               1             134.8                37.8             2813.5
# 1               2             113.1                30.6             2241.0
# 2               3             108.2                21.3             2359.1
# 3               4             147.4                13.6              685.3
# 4               5             420.7                44.9              333.8
# ...           ...               ...                 ...                ...
# 1919         1995               4.7                 0.3                1.7
# 1920         1996               0.5                 0.1               25.7
# 1921         1996               0.9                 0.7                7.8
# 1922         1998               2.4                 0.2               14.6
# 1923         1999               5.0                -0.1               16.2
#
#       Market Value ($billion)   Latitude   Longitude
# ...

# %%
cat_cols=df.select_dtypes(include=["O"])
cat_cols
# Out:
#                          Company    Country      Continent
# 0                           ICBC      China           Asia
# 1        China Construction Bank      China           Asia
# 2                 JPMorgan Chase        USA  North America
# 3               General Electric        USA  North America
# 4                    Exxon Mobil        USA  North America
# ...                          ...        ...            ...
# 1919              Tractor Supply        USA  North America
# 1920                  San-Ai Oil      Japan           Asia
# 1921                   UOL Group  Singapore           Asia
# 1922     Interconexion Electrica   Colombia  South America
# 1923  Old Republic International        USA  North America
#
# [1924 rows x 3 columns]

# %% [markdown]
# # There is no null value in dataset it is clean dataset

# %%
df.isnull().sum()
# Out:
# Global Rank                0
# Company                    0
# Sales ($billion)           0
# Profits ($billion)         0
# Assets ($billion)          0
# Market Value ($billion)    0
# Country                    0
# Continent                  0
# Latitude                   0
# Longitude                  0
# dtype: int64

# %% [markdown]
# # data Visualization particular output with garph

# %% [markdown]
# # 1:- Find out highest market value earn company in global rightnow.

# %%
mn=df["Market Value ($billion)"].max()
mn
# Out:
# 416.6

# %%
df["Company"].loc[df["Market Value ($billion)"]==mn]
# Out:
# 15    Apple
# Name: Company, dtype: object

# %% [markdown]
# # 2:- find out the company highest profit gain company

# %%
pf=df["Profits ($billion)"].max()
pf
# Out:
# 44.9

# %%
df["Company"].loc[df["Profits ($billion)"]==pf]
# Out:
# 4    Exxon Mobil
# Name: Company, dtype: object

# %% [markdown]
# # 3:-In whole dataset which country has most company

# %%
df.head(2)
# Out:
#    Global Rank                  Company  Sales ($billion)  Profits ($billion)  \
# 0            1                     ICBC             134.8                37.8
# 1            2  China Construction Bank             113.1                30.6
#
#    Assets ($billion)  Market Value ($billion) Country Continent  Latitude  \
# 0             2813.5                    237.3   China      Asia  35.86166
# 1             2241.0                    202.0   China      Asia  35.86166
#
#     Longitude
# 0  104.195397
# 1  104.195397

# %%
tt=df["Country"]=="Vietnam"
tt
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1919    False
# 1920    False
# 1921    False
# 1922    False
# 1923    False
# Name: Country, Length: 1924, dtype: bool

# %%
df["Company"].loc[df["Country"]==tt]
# Out:
# Series([], Name: Company, dtype: object)

# %% [markdown]
# # 4:- company most sales in dataset

# %%
sales=df["Sales ($billion)"].max()
sales
# Out:
# 469.2

# %%
df["Company"].loc[df["Sales ($billion)"]==sales]
# Out:
# 14    Wal-Mart Stores
# Name: Company, dtype: object

# %% [markdown]
# # 5:- company has lowest market value i dataset

# %%
mr=df["Market Value ($billion)"].min()
mr
# Out:
# 0.0

# %%
df["Company"].loc[df["Market Value ($billion)"]==mr]
# Out:
# 1882    Ambac Financial Group
# Name: Company, dtype: object

# %%
df.head()
# Out:
#    Global Rank                  Company  Sales ($billion)  Profits ($billion)  \
# 0            1                     ICBC             134.8                37.8
# 1            2  China Construction Bank             113.1                30.6
# 2            3           JPMorgan Chase             108.2                21.3
# 3            4         General Electric             147.4                13.6
# 4            5              Exxon Mobil             420.7                44.9
#
#    Assets ($billion)  Market Value ($billion) Country      Continent  \
# 0             2813.5                    237.3   China           Asia
# 1             2241.0                    202.0   China           Asia
# 2             2359.1                    191.4     USA  North America
# 3              685.3                    243.7     USA  North America
# 4              333.8                    400.4     USA  North America
#
#    Latitude   Longitude
# 0  35.86166  104.195397
# 1  35.86166  104.195397
# ...

# %% [markdown]
# # 6:-which company has maximum longitude

# %%
ln=df["Longitude"].max()
ln
# Out:
# 174.885971

# %%
df["Company"].loc[df["Longitude"]==ln]
# Out:
# 1754    Telecom of New Zealand
# Name: Company, dtype: object

# %% [markdown]
# # 7:-which company has most in the dataset

# %%
d=df["Company"]=="USA"
d
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1919    False
# 1920    False
# 1921    False
# 1922    False
# 1923    False
# Name: Company, Length: 1924, dtype: bool

# %%
df["Company"].loc[df["Country"]==d]
# Out:
# Series([], Name: Company, dtype: object)

# %%
df["Country"].value_counts()
# Out:
# USA                     535
# Japan                   246
# China                   135
# UK                       97
# Canada                   65
# South Korea              64
# France                   64
# India                    56
# Germany                  50
# Hong Kong                46
# Australia                42
# Taiwan                   40
# Brazil                   31
# Russia                   30
# Italy                    29
# Spain                    28
# Sweden                   26
# The Netherlands          24
# Singapore                20
# Malaysia                 20
# South Africa             19
# Mexico                   19
# Saudi Arabia             17
# Ireland                  17
# Thailand                 16
# Turkey                   14
# United Arab Emirates     14
# Finland                  12
# Belgium                  11
# Norway                   10
# Denmark                  10
# Israel                   10
# Greece                   10
# ...

# %%
df.tail()
# Out:
#       Global Rank                     Company  Sales ($billion)  \
# 1919         1995              Tractor Supply               4.7
# 1920         1996                  San-Ai Oil               0.5
# 1921         1996                   UOL Group               0.9
# 1922         1998     Interconexion Electrica               2.4
# 1923         1999  Old Republic International               5.0
#
#       Profits ($billion)  Assets ($billion)  Market Value ($billion)  \
# 1919                 0.3                1.7                      7.1
# 1920                 0.1               25.7                      0.5
# 1921                 0.7                7.8                      4.2
# 1922                 0.2               14.6                      5.8
# 1923                -0.1               16.2                      3.3
#
#         Country      Continent   Latitude   Longitude
# 1919        USA  North America  37.090240  -95.712891
# 1920      Japan           Asia  36.204824  138.252924
# ...

# %% [markdown]
# # 8:- In the dataset all the company from asia continent

# %%
con=df["Continent"]=="Asia" 
con
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1919    False
# 1920     True
# 1921     True
# 1922    False
# 1923    False
# Name: Continent, Length: 1924, dtype: bool

# %%
asia_company=df[con]
asia_company
# Out:
#       Global Rank                     Company  Sales ($billion)  \
# 0               1                        ICBC             134.8
# 1               2     China Construction Bank             113.1
# 7               8  Agricultural Bank of China             103.0
# 8               9                  PetroChina             308.9
# 10             11               Bank of China              98.1
# ...           ...                         ...               ...
# 1911         1987         Poly Property Group               2.7
# 1916         1992            LG International              11.4
# 1918         1994                Bank of Saga               0.5
# 1920         1996                  San-Ai Oil               0.5
# 1921         1996                   UOL Group               0.9
#
#       Profits ($billion)  Assets ($billion)  Market Value ($billion)  \
# 0                   37.8             2813.5                    237.3
# ...

# %%
df[df["Continent"]=="Asia"]["Company"]
# Out:
# 0                             ICBC
# 1          China Construction Bank
# 7       Agricultural Bank of China
# 8                       PetroChina
# 10                   Bank of China
#                    ...
# 1911           Poly Property Group
# 1916              LG International
# 1918                  Bank of Saga
# 1920                    San-Ai Oil
# 1921                     UOL Group
# Name: Company, Length: 719, dtype: object

# %% [markdown]
# # 9:- find out the average profit ratio of the companies

# %%
df["Profits ($billion)"].mean()
# Out:
# 1.226039501039501

# %% [markdown]
# # 10:- find out the indian company in the dataset

# %%
ind=df["Country"]=="India"
ind
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1919    False
# 1920    False
# 1921    False
# 1922    False
# 1923    False
# Name: Country, Length: 1924, dtype: bool

# %%
indian_company=df[ind]
indian_company
# Out:
#       Global Rank                    Company  Sales ($billion)  \
# 116           121        Reliance Industries              70.3
# 129           136        State Bank of India              35.1
# 148           155          Oil & Natural Gas              28.9
# 297           309                 ICICI Bank              13.2
# 321           334                Tata Motors              32.6
# 337           350                 Indian Oil              70.8
# 362           377                 Coal India              12.3
# 369           384                       NTPC              12.8
# 436           456              Bharti Airtel              14.0
# 443           463                  HDFC Bank               6.5
# 507           527            Larsen & Toubro              12.6
# 540           561                       HDFC               5.9
# 569           590                 Tata Steel              26.1
# 614           636  Tata Consultancy Services               9.6
# ...

# %% [markdown]
# # Data vesulization

# %% [markdown]
# # 1:- Bar Graph

# %%
# Assuming df is your DataFrame
top_10_sales = df.nlargest(10, 'Sales ($billion)')

plt.figure(figsize=(12, 6))
plt.bar(top_10_sales['Company'], top_10_sales['Sales ($billion)'])
plt.xlabel('Company')
plt.ylabel('Sales ($billion)')

plt.title('Top 10 Companies by Sales')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# It is Bar graph tha show the top ten company by sales in the dataset. the Data show in x axise are the company and the  are the name pf company and the yasixe are show sales perform in whole year it show in the data set.

# %% [markdown]
# # 2:- Scatter plot

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Sales ($billion)'], df['Market Value ($billion)'])
plt.xlabel('Sales ($billion)')
plt.ylabel('Market Value ($billion)')
plt.title('Scatter Plot: Sales vs. Market Value')
plt.show()

# %% [markdown]
# # 3:- line chart

# %%
profits_over_rank= df.groupby('Global Rank')['Profits ($billion)'].sum()

plt.figure(figsize=(10, 5))
profits_over_rank.plot(kind='line')
plt.xlabel('Global Rank')
plt.ylabel('Total Profits ($billion)')
plt.title('Total Profits Over rank')
plt.show()

# %% [markdown]
# # 4:- histograph

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Profits ($billion)'], bins=20, edgecolor='k')
plt.xlabel('Profits ($billion)')
plt.ylabel('Frequency')
plt.title('Distribution of Company Profits')
plt.show()

# %% [markdown]
# # 5:- pie graph

# %%
continent_counts = df['Continent'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(continent_counts, labels=continent_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Companies by Continent')
plt.show()

# %% [markdown]
# # 6:- boxplot

# %%
plt.figure(figsize=(10, 6))
plt.boxplot([df[df['Continent'] == 'Asia']['Sales ($billion)'], 
             df[df['Continent'] == 'Europe']['Sales ($billion)'], 
             df[df['Continent'] == 'North America']['Sales ($billion)']], 
            labels=['Asia', 'Europe', 'North America'])
plt.xlabel('Continent')
plt.ylabel('Sales ($billion)')
plt.title('Sales Distribution by Continent (Box Plot)')
plt.show()

# %% [markdown]
# # 7:- Bar graph

# %%
top_10_sales_profits = df.nlargest(10, 'Sales ($billion)')[['Company', 'Sales ($billion)', 'Profits ($billion)']]

plt.figure(figsize=(12, 6))
plt.bar(top_10_sales_profits['Company'], top_10_sales_profits['Sales ($billion)'], label='Sales')
plt.bar(top_10_sales_profits['Company'], top_10_sales_profits['Profits ($billion)'], label='Profits', bottom=top_10_sales_profits['Sales ($billion)'])
plt.xlabel('Company')
plt.ylabel('Amount ($billion)')
plt.title('Sales and Profits for Top 10 Companies')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
companyname=df["Market Value ($billion)"].head(10)
companyname
name=df["Company"].head()
name
# Out:
# 0                       ICBC
# 1    China Construction Bank
# 2             JPMorgan Chase
# 3           General Electric
# 4                Exxon Mobil
# Name: Company, dtype: object

# %% [markdown]
# # 8:- Pie Chart

# %%
plt.figure(figsize=(8, 8))
plt.pie(companyname,labels=companyname.index, autopct='%1.1f%%')
plt.title('Distribution of Companies by Continent')
plt.show()
